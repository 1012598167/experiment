# %%
import pandas as pd
train=pd.read_excel("train.xlsx")
train.head(10)
# Out:
#    Unnamed: 0  Frequency  Departure Airport Arrival Airport Airport Routing  \
# 0           0           2               SWA             HAK         SWA-HAK
# 1           1           2               HAK             SWA         HAK-SWA
# 2           2           1               SWA             WUH         SWA-WUH
# 3           3           1               WUH             SWA         WUH-SWA
# 4           4          14               HAK             LZH     HAK-LZH-PEK
# 5           5          14               PEK             LZH     PEK-LZH-HAK
# 6           6           7               KMG             TSN         KMG-TSN
# 7           7           7               TSN             KMG         TSN-KMG
# 8           8           4               HET             SYX     DSN-HET-SYX
# 9           9          14               HET             HRB     HET-HRB-HLD
#
#      frequency Dairport Aairport
# 0      SWA-HAK       汕头       海口
# 1      HAK-SWA       海口       汕头
# ...

# %%
train['Dairport'].groupby()

# %%
train.groupby(['Dairport'])['Frequency_'].sum()
# Out:
# Dairport
# 三亚              5676
# 上海             43150
# 东营               172
# 中卫               104
# 临沂               920
#                ...
# 黑河               168
# 黔南布依族苗族自治州        20
# 黔西南布依族苗族自治州      108
# 齐齐哈尔             106
# 龙岩                71
# Name: Frequency_, Length: 158, dtype: int64

# %%
    b=train.groupby(['Aairport'])['Frequency_'].sum()

# %%
b
# Out:
# Aairport
# 三亚              5601
# 上海             39352
# 东营               172
# 中卫               104
# 临沂               304
#                ...
# 黑河               168
# 黔南布依族苗族自治州        16
# 黔西南布依族苗族自治州      108
# 齐齐哈尔             202
# 龙岩                71
# Name: Frequency_, Length: 158, dtype: int64

# %%
a=train.groupby(['Dairport'])['Frequency_'].sum()

# %%
a
# Out:
# Dairport
# 三亚              5676
# 上海             43150
# 东营               172
# 中卫               104
# 临沂               920
#                ...
# 黑河               168
# 黔南布依族苗族自治州        20
# 黔西南布依族苗族自治州      108
# 齐齐哈尔             106
# 龙岩                71
# Name: Frequency_, Length: 158, dtype: int64

# %%
b
# Out:
# Aairport
# 三亚              5601
# 上海             39352
# 东营               172
# 中卫               104
# 临沂               304
#                ...
# 黑河               168
# 黔南布依族苗族自治州        16
# 黔西南布依族苗族自治州      108
# 齐齐哈尔             202
# 龙岩                71
# Name: Frequency_, Length: 158, dtype: int64

# %%
for index,items in b.iteritems():
    if index in a:
        a[index]+=items
    else:
        print(index)
        a.append(pd.Series([items],index=[index]))
a
# Out:
# 怀化
# 永州
# 金门
# Dairport
# 三亚             11277
# 上海             82502
# 东营               344
# 中卫               208
# 临沂              1224
#                ...
# 黑河               336
# 黔南布依族苗族自治州        36
# 黔西南布依族苗族自治州      216
# 齐齐哈尔             308
# 龙岩               142
# Name: Frequency_, Length: 158, dtype: int64

# %%
a.to_excel("city_airport_freq.xlsx")

# %%
train.tail(10)
# Out:
#       Unnamed_0  Frequency_ Departure_Airport Arrival_Airport Airport_Routing  \
# 3469       4338         161               HKG             HAK         HKG-HAK
# 3470       4339         161               HAK             HKG         HAK-HKG
# 3471       4340        2502               HKG             PVG         HKG-PVG
# 3472       4341        2502               PVG             HKG         PVG-HKG
# 3473       4342         456               HKG             XMN         HKG-XMN
# 3474       4343         456               XMN             HKG         XMN-HKG
# 3475       4344        1488               HKG             PEK         HKG-PEK
# 3476       4345        1488               PEK             HKG         PEK-HKG
# 3477       4346          36               HKG             HRB         HKG-HRB
# 3478       4347          36               HRB             HKG         HRB-HKG
#
#      frequency Dairport Aairport
# 3469   HKG-HAK       香港       海口
# 3470   HAK-HKG       海口       香港
# ...

# %%
train.head(30)
# Out:
#     Unnamed_0  Frequency_ Departure_Airport Arrival_Airport Airport_Routing  \
# 0           0           2               SWA             HAK         SWA-HAK
# 1           1           2               HAK             SWA         HAK-SWA
# 2           2           1               SWA             WUH         SWA-WUH
# 3           3           1               WUH             SWA         WUH-SWA
# 4           4          14               HAK             LZH     HAK-LZH-PEK
# 5           5          14               PEK             LZH     PEK-LZH-HAK
# 6           6           7               KMG             TSN         KMG-TSN
# 7           7           7               TSN             KMG         TSN-KMG
# 8           8           4               HET             SYX     DSN-HET-SYX
# 9           9          14               HET             HRB     HET-HRB-HLD
# 10         10          14               HLD             HRB     HLD-HRB-HET
# ...

# %%
import pandas_profiling
pandas_profiling.ProfileReport(train)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
bb=set()
bb.add("1")
bb.add("1")

bb
len(bb)
# Out:
# 1

# %%
pait=train.apply(lambda x:x['Airport_Routing'].split('-'),axis=1)

# %%
'123'.split('2')
# Out:
# ['1', '3']

# %%
a=[]
for index,items in pait.iteritems():
    for i in items:
        print('###',i)
        if i not in a:
            a.extend(items)
print(a)
# Out:
# ### SWA
# ### HAK
# ### HAK
# ### SWA
# ### SWA
# ### WUH
# ### WUH
# ### SWA
# ### HAK
# ### LZH
# ### PEK
# ### PEK
# ### LZH
# ### HAK
# ### KMG
# ### TSN
# ### TSN
# ### KMG
# ### DSN
# ### HET
# ### SYX
# ### HET
# ### HRB
# ### HLD
# ### HLD
# ### HRB
# ### HET
# ### INC
# ### CGO
# ### HGH
# ### HGH
# ### CGO
# ### INC
# ### HAK
# ### HET
# ### HET
# ### HAK
# ### CKG
# ### CGO
# ### BAV
# ### BAV
# ### CGO
# ### CKG
# ### CAN
# ### CGQ
# ### CGQ
# ### CAN
# ### TNA
# ### FOC
# ### HAK
# ### HAK
# ### FOC
# ### TNA
# ### XIY
# ### THQ
# ### LHW
# ### LHW
# ### THQ
# ### XIY
# ### FOC
# ### MFM
# ### MFM
# ### FOC
# ### XIY
# ### TSA
# ### TSA
# ### XIY
# ### FOC
# ### KHN
# ### KHN
# ### FOC
# ### CPH
# ### FRA
# ### PVG
# ### CGQ
# ### CGO
# ### HAK
# ### HAK
# ### CGO
# ### CGQ
# ### SHE
# ### HAK
# ### HAK
# ### SHE
# ### KIX
# ### DLC
# ### SHE
# ### KWE
# ### NNG
# ### NNG
# ### KWE
# ### CKG
# ### KHN
# ### NGB
# ### NGB
# ### KHN
# ### CKG
# ### XMN
# ### NKG
# ### SJW
# ...

# %%
len(list(set(a)))
# Out:
# 208

# %%
b=set()

# %%
b.add('1')
b.add('2')

# %%
b
# Out:
# {'1', '2'}

# %%
c=set()

# %%
c.add("2")
c.add("1")

# %%
b==c
# Out:
# True

# %%
a=[]
for index,rows in train.iterrows():
    b=set()
    b.add(rows['Dairport'])
    b.add(rows['Aairport'])
    a.append(b)

# %%
b=[]
for i in a:
    if i not in b:
        b.append(i)
len(b)
# Out:
# 1108

# %%
b
# Out:
# [{'汕头', '海口'},
#  {'武汉', '汕头'},
#  {'柳州', '海口'},
#  {'北京', '柳州'},
#  {'天津', '昆明'},
#  {'三亚', '呼和浩特'},
#  {'呼和浩特', '哈尔滨'},
#  {'呼伦贝尔', '哈尔滨'},
#  {'杭州', '郑州'},
#  {'郑州', '银川'},
#  {'呼和浩特', '海口'},
#  {'包头', '郑州'},
#  {'郑州', '重庆'},
#  {'广州', '长春'},
#  {'济南', '福州'},
#  {'海口', '福州'},
#  {'兰州', '天水'},
#  {'天水', '西安'},
#  {'澳门', '福州'},
#  {'台北', '西安'},
#  {'南昌', '福州'},
#  {nan, '上海'},
#  {'海口', '郑州'},
#  {'郑州', '长春'},
#  {'沈阳', '海口'},
#  {'大连', '沈阳'},
#  {'南宁', '贵阳'},
#  {'南昌', '宁波'},
#  {'南昌', '重庆'},
#  {'南京', '石家庄'},
#  {'重庆', '长沙'},
#  {'福州', '长沙'},
#  {'南昌', '泉州'},
#  {'上海', '南平'},
#  {nan, '广州'},
#  {'天津', '宁波'},
#  {'哈尔滨', '天津'},
#  {'三亚', '石家庄'},
#  {'三亚', '宁波'},
#  {'南京', '温州'},
#  {'上海', '宁波'},
#  {nan, '延边朝鲜族自治州'},
#  {'海口', '石家庄'},
#  {'哈尔滨', '太原'},
#  {'南宁', '太原'},
#  {'南宁', '合肥'},
#  {'合肥', '哈尔滨'},
#  {'厦门', '邯郸'},
#  {'西安', '邯郸'},
#  {'海口', '深圳'},
#  {'深圳', '烟台'},
#  {'济南', '烟台'},
#  {'哈尔滨', '烟台'},
#  {'合肥', '济南'},
#  {'合肥', '桂林'},
#  {'烟台', '长春'},
#  {'大连', '郑州'},
# ...

# %%
b=[]
for i in a:
    if i not in b:
        b.append(i)
len(b)
# Out:
# 1193

# %%
a=[]
for index,rows in train.iterrows():
    b=set()
    b.add(rows['Departure_Airport'])
    b.add(rows['Arrival_Airport'])
    a.append(b)
len(list(set(a)))

# %%
len(a)
# Out:
# 3479

# %%
a=[]
for index,rows in train.iterrows():
    b=set()
    b.add(rows['Departure_Airport'])
    b.add(rows['Arrival_Airport'])
    a.append(b)
len(list(set(a)))

# %%
dd=set()

# %%
Dairport

# %%
Aairport

# %%
for index,rows in train.iterrows():
    dd.add(rows['Dairport'])
    dd.add(rows['Aairport'])
len(dd)
# Out:
# 162

# %%
cc
# Out:
# {nan,
#  '三亚',
#  '上海',
#  '东营',
#  '中卫',
#  '临沂',
#  '临沧',
#  '丹东',
#  '丽江',
#  '乌兰浩特',
#  '乌海',
#  '乌鲁木齐',
#  '九寨沟',
#  '九江',
#  '伊宁',
#  '伊春',
#  '伊犁哈萨克自治州',
#  '佛山',
#  '保山',
#  '克拉玛依',
#  '兰州',
#  '凉山彝族自治州',
#  '包头',
#  '北京',
#  '北海',
#  '南京',
#  '南充',
#  '南宁',
#  '南平',
#  '南昌',
#  '南通',
#  '南阳',
#  '厦门',
#  '台北',
#  '台州',
#  '合肥',
#  '吉安',
#  '呼伦贝尔',
#  '呼和浩特',
#  '和田',
#  '哈密',
#  '哈尔滨',
#  '喀什',
#  '喀纳斯',
#  '嘉峪关',
#  '塔城',
#  '大同',
#  '大庆',
#  '大理',
#  '大连',
#  '天水',
#  '天津',
#  '太原',
#  '威海',
#  '宁波',
#  '安庆',
#  '安康',
#  '宜宾',
#  '宜昌',
#  '巴音郭楞蒙古族自治州',
#  '巴音郭楞蒙古自治州',
#  '常州',
#  '常德',
#  '广元',
#  '广州',
#  '庆阳',
#  '延安',
#  '延边朝鲜族自治州',
#  '张家界',
#  '徐州',
#  '德宏',
#  '恩施',
#  '成都',
#  '拉萨',
#  '攀枝花',
#  '文山',
#  '无锡',
#  '昆明',
#  '昌都',
#  '昭通',
#  '普洱',
#  '景德镇',
#  '朝阳',
#  '杭州',
#  '林芝',
#  '柳州',
#  '桂林',
#  '梅州',
#  '梧州',
#  '榆林',
#  '武汉',
#  '汉中',
#  '汕头',
#  '沈阳',
#  '泉州',
#  '泸州',
#  '洛阳',
#  '济南',
#  '济宁',
#  '海口',
#  '深圳',
#  '温州',
#  '湛江',
#  '满洲里',
#  '漠河',
# ...

# %%
dd-cc
# Out:
# {'怀化', '永州', '金门'}

# %%
for index,rows in train.iterrows():
    if pd.isna(rows['Dairport']) or pd.isna(rows['Dairport']):
        print(index)
        print(rows)
# Out:
# 29
# Unnamed_0                     41
# Frequency_                     2
# Departure_Airport            FRA
# Arrival_Airport              PVG
# Airport_Routing      CPH-FRA-PVG
# frequency            CPH-FRA-PVG
# Dairport                     NaN
# Aairport                      上海
# Name: 29, dtype: object
# 46
# Unnamed_0                     61
# Frequency_                    14
# Departure_Airport            NRT
# Arrival_Airport              CAN
# Airport_Routing      SFO-NRT-CAN
# frequency            SFO-NRT-CAN
# Dairport                     NaN
# Aairport                      广州
# Name: 46, dtype: object
# 98
# Unnamed_0                    121
# Frequency_                    12
# Departure_Airport            KHI
# Arrival_Airport              URC
# Airport_Routing      KHI-URC-PEK
# frequency            KHI-URC-PEK
# Dairport                     NaN
# Aairport                    乌鲁木齐
# Name: 98, dtype: object
# 112
# Unnamed_0                    139
# ...
